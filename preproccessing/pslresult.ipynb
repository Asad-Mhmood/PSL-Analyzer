# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('PSL-2016-2022.csv')

# %%
df.tail()
# Out:
#        psl_year  match_number            team_1          team_2  inning  over  \
# 50257      2022            34  Lahore Qalandars  Multan Sultans       2    19
# 50258      2022            34  Lahore Qalandars  Multan Sultans       2    19
# 50259      2022            34  Lahore Qalandars  Multan Sultans       2    20
# 50260      2022            34  Lahore Qalandars  Multan Sultans       2    20
# 50261      2022            34  Lahore Qalandars  Multan Sultans       2    20
#
#        ball  runs  wicket  total_runs  wickets  is_four  is_six  is_wicket  \
# 50257     5     0     2.0         138        9    False   False       True
# 50258     6     0     NaN         138        9    False   False      False
# 50259     1     0     NaN         138        9    False   False      False
# 50260     2     0     NaN         138        9    False   False      False
# 50261     3     0     1.0         138       10    False   False       True
#
#       wicket_text     result
# 50257      bowled  Qalandars
# 50258         NaN  Qalandars
# 50259         NaN  Qalandars
# 50260         NaN  Qalandars
# 50261      caught  Qalandars

# %%
df.shape
# Out:
# (50262, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50262 entries, 0 to 50261
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   psl_year      50262 non-null  int64
#  1   match_number  50262 non-null  int64
#  2   team_1        50262 non-null  object
#  3   team_2        50262 non-null  object
#  4   inning        50262 non-null  int64
#  5   over          50262 non-null  int64
#  6   ball          50262 non-null  int64
#  7   runs          50262 non-null  int64
#  8   wicket        2661 non-null   float64
#  9   total_runs    50262 non-null  int64
#  10  wickets       50262 non-null  int64
#  11  is_four       50262 non-null  bool
#  12  is_six        50262 non-null  bool
#  13  is_wicket     50262 non-null  bool
#  14  wicket_text   2650 non-null   object
#  15  result        50262 non-null  object
# dtypes: bool(3), float64(1), int64(8), object(4)
# memory usage: 5.1+ MB

# %%
print("Number of matches in each year")
df.groupby("psl_year")['match_number'].nunique()
# Out:
# Number of matches in each year
# psl_year
# 2016    24
# 2017    24
# 2018    33
# 2019    34
# 2020    32
# 2021    34
# 2022    34
# Name: match_number, dtype: int64

# %%
df.groupby(["psl_year","wicket_text"])["wicket_text"].count()
# Out:
# psl_year  wicket_text
# 2016      bowled             45
#           caught            172
#           hit wicket          1
#           lbw                26
#           run out            26
#           stumped            10
# 2017      bowled             48
#           caught            191
#           lbw                28
#           run out            36
#           stumped             9
# 2018      bowled             84
#           caught            261
#           hit wicket          2
#           lbw                32
#           run out            31
#           stumped             5
# 2019      bowled             93
#           caught            256
#           lbw                28
#           obstruct field      1
#           run out            42
#           stumped            10
# 2020      bowled             58
#           caught            267
#           lbw                16
#           run out            27
#           stumped             5
# 2021      bowled             86
#           caught            247
#           hit wicket          2
#           lbw                39
#           run out            34
#           stumped             5
# 2022      bowled             82
#           caught            275
#           lbw                32
#           run out            29
#           stumped             9
# Name: wicket_text, dtype: int64

# %%
df["wicket"].unique()
# Every value of this column represent the wicket
# Out:
# array([nan,  1.,  2.,  3.,  4.,  5.,  6.,  8.])

# %%
df2=df.loc[df["runs"] == 4].groupby(["psl_year"])["runs"].count().reset_index()
df2
# Out:
#    psl_year  runs
# 0      2016   578
# 1      2017   565
# 2      2018   792
# 3      2019   898
# 4      2020   884
# 5      2021  1022
# 6      2022  1008

# %%
sns.barplot(data=df2, x=df2["psl_year"],y=df2["runs"])
# Out:
# <AxesSubplot:xlabel='psl_year', ylabel='runs'>

# %%
df3=df.loc[df["runs"] == 6].groupby(["psl_year"])["runs"].count().reset_index()
df3
# Out:
#    psl_year  runs
# 0      2016   246
# 1      2017   256
# 2      2018   413
# 3      2019   374
# 4      2020   383
# 5      2021   431
# 6      2022   434

# %%
sns.barplot(data=df3, x=df3["psl_year"],y=df3["runs"])
# Out:
# <AxesSubplot:xlabel='psl_year', ylabel='runs'>

# %%
df.isnull().sum()
# Out:
# psl_year            0
# match_number        0
# team_1              0
# team_2              0
# inning              0
# over                0
# ball                0
# runs                0
# wicket          47601
# total_runs          0
# wickets             0
# is_four             0
# is_six              0
# is_wicket           0
# wicket_text     47612
# result              0
# dtype: int64

# %%
df.sample(5)
# Out:
#        psl_year  match_number            team_1            team_2  inning  \
# 32577      2020            29    Multan Sultans  Lahore Qalandars       1
# 8219       2017            12    Peshawar Zalmi  Islamabad United       2
# 40315      2021            27     Karachi Kings  Lahore Qalandars       2
# 16445      2018            24     Karachi Kings  Lahore Qalandars       2
# 31319      2020            22  Islamabad United    Multan Sultans       2
#
#        over  ball  runs  wicket  total_runs  wickets  is_four  is_six  \
# 32577     5     4     0     NaN          24        2    False   False
# 8219     17     8     6     NaN         111        4    False    True
# 40315    20     5     4     NaN         169        7     True   False
# 16445    11     1     1     NaN          83        1    False   False
# 31319     5     1     0     NaN          62        0    False   False
#
#        is_wicket wicket_text     result
# 32577      False         NaN  Qalandars
# 8219       False         NaN     United
# 40315      False         NaN      Kings
# 16445      False         NaN       tied
# 31319      False         NaN    Sultans

# %%
df["wicket_text"].unique()
# Out:
# array([nan, 'caught', 'bowled', 'lbw', 'run out', 'stumped', 'hit wicket',
#        'obstruct field'], dtype=object)

# %%
df["wicket_text"].fillna('not out',inplace=True)

# %%
df.isnull().sum()
# Out:
# psl_year            0
# match_number        0
# team_1              0
# team_2              0
# inning              0
# over                0
# ball                0
# runs                0
# wicket          47601
# total_runs          0
# wickets             0
# is_four             0
# is_six              0
# is_wicket           0
# wicket_text         0
# result              0
# dtype: int64

# %%
df["wicket"].unique()
# Out:
# array([nan,  1.,  2.,  3.,  4.,  5.,  6.,  8.])

# %%
df[df["wicket_text"]=='bowled']
# Out:
#        psl_year  match_number            team_1             team_2  inning  \
# 48         2016             1  Islamabad United  Quetta Gladiators       1
# 55         2016             1  Islamabad United  Quetta Gladiators       1
# 253        2016             2  Lahore Qalandars      Karachi Kings       1
# 336        2016             2  Lahore Qalandars      Karachi Kings       1
# 346        2016             2  Lahore Qalandars      Karachi Kings       1
# ...         ...           ...               ...                ...     ...
# 50164      2022            34  Lahore Qalandars     Multan Sultans       2
# 50189      2022            34  Lahore Qalandars     Multan Sultans       2
# 50244      2022            34  Lahore Qalandars     Multan Sultans       2
# 50248      2022            34  Lahore Qalandars     Multan Sultans       2
# 50257      2022            34  Lahore Qalandars     Multan Sultans       2
#
#        over  ball  runs  wicket  total_runs  wickets  is_four  is_six  \
# 48        8     6     0     2.0          28        3    False   False
# 55       10     1     0     2.0          32        4    False   False
# 253       5     6     0     2.0          37        2    False   False
# 336      19     2     0     2.0         117        5    False   False
# 346      20     5     0     2.0         124        8    False   False
# ...     ...   ...   ...     ...         ...      ...      ...     ...
# 50164     4     6     0     2.0          36        1    False   False
# 50189     8     6     0     2.0          50        4    False   False
# 50244    17     5     0     2.0         120        7    False   False
# 50248    18     2     0     2.0         122        8    False   False
# 50257    19     5     0     2.0         138        9    False   False
#
#        is_wicket wicket_text      result
# 48          True      bowled  Gladiators
# 55          True      bowled  Gladiators
# 253         True      bowled       Kings
# 336         True      bowled       Kings
# 346         True      bowled       Kings
# ...          ...         ...         ...
# 50164       True      bowled   Qalandars
# 50189       True      bowled   Qalandars
# 50244       True      bowled   Qalandars
# 50248       True      bowled   Qalandars
# 50257       True      bowled   Qalandars
#
# [496 rows x 16 columns]

# %%
df.drop(columns=['wicket'],inplace=True)

# %%
df.head(60)
# Out:
#     psl_year  match_number            team_1             team_2  inning  over  \
# 0       2016             1  Islamabad United  Quetta Gladiators       1     1
# 1       2016             1  Islamabad United  Quetta Gladiators       1     1
# 2       2016             1  Islamabad United  Quetta Gladiators       1     1
# 3       2016             1  Islamabad United  Quetta Gladiators       1     1
# 4       2016             1  Islamabad United  Quetta Gladiators       1     1
# 5       2016             1  Islamabad United  Quetta Gladiators       1     1
# 6       2016             1  Islamabad United  Quetta Gladiators       1     2
# 7       2016             1  Islamabad United  Quetta Gladiators       1     2
# 8       2016             1  Islamabad United  Quetta Gladiators       1     2
# 9       2016             1  Islamabad United  Quetta Gladiators       1     2
# 10      2016             1  Islamabad United  Quetta Gladiators       1     2
# 11      2016             1  Islamabad United  Quetta Gladiators       1     2
# 12      2016             1  Islamabad United  Quetta Gladiators       1     3
# 13      2016             1  Islamabad United  Quetta Gladiators       1     3
# 14      2016             1  Islamabad United  Quetta Gladiators       1     3
# 15      2016             1  Islamabad United  Quetta Gladiators       1     3
# 16      2016             1  Islamabad United  Quetta Gladiators       1     3
# 17      2016             1  Islamabad United  Quetta Gladiators       1     3
# 18      2016             1  Islamabad United  Quetta Gladiators       1     4
# 19      2016             1  Islamabad United  Quetta Gladiators       1     4
# 20      2016             1  Islamabad United  Quetta Gladiators       1     4
# 21      2016             1  Islamabad United  Quetta Gladiators       1     4
# 22      2016             1  Islamabad United  Quetta Gladiators       1     4
# 23      2016             1  Islamabad United  Quetta Gladiators       1     4
# 24      2016             1  Islamabad United  Quetta Gladiators       1     5
# 25      2016             1  Islamabad United  Quetta Gladiators       1     5
# 26      2016             1  Islamabad United  Quetta Gladiators       1     5
# 27      2016             1  Islamabad United  Quetta Gladiators       1     5
# 28      2016             1  Islamabad United  Quetta Gladiators       1     5
# 29      2016             1  Islamabad United  Quetta Gladiators       1     5
# 30      2016             1  Islamabad United  Quetta Gladiators       1     6
# 31      2016             1  Islamabad United  Quetta Gladiators       1     6
# 32      2016             1  Islamabad United  Quetta Gladiators       1     6
# 33      2016             1  Islamabad United  Quetta Gladiators       1     6
# 34      2016             1  Islamabad United  Quetta Gladiators       1     6
# 35      2016             1  Islamabad United  Quetta Gladiators       1     6
# 36      2016             1  Islamabad United  Quetta Gladiators       1     7
# 37      2016             1  Islamabad United  Quetta Gladiators       1     7
# 38      2016             1  Islamabad United  Quetta Gladiators       1     7
# 39      2016             1  Islamabad United  Quetta Gladiators       1     7
# 40      2016             1  Islamabad United  Quetta Gladiators       1     7
# 41      2016             1  Islamabad United  Quetta Gladiators       1     7
# 42      2016             1  Islamabad United  Quetta Gladiators       1     7
# 43      2016             1  Islamabad United  Quetta Gladiators       1     8
# 44      2016             1  Islamabad United  Quetta Gladiators       1     8
# 45      2016             1  Islamabad United  Quetta Gladiators       1     8
# 46      2016             1  Islamabad United  Quetta Gladiators       1     8
# 47      2016             1  Islamabad United  Quetta Gladiators       1     8
# 48      2016             1  Islamabad United  Quetta Gladiators       1     8
# 49      2016             1  Islamabad United  Quetta Gladiators       1     9
# 50      2016             1  Islamabad United  Quetta Gladiators       1     9
# 51      2016             1  Islamabad United  Quetta Gladiators       1     9
# 52      2016             1  Islamabad United  Quetta Gladiators       1     9
# 53      2016             1  Islamabad United  Quetta Gladiators       1     9
# 54      2016             1  Islamabad United  Quetta Gladiators       1     9
# 55      2016             1  Islamabad United  Quetta Gladiators       1    10
# 56      2016             1  Islamabad United  Quetta Gladiators       1    10
# 57      2016             1  Islamabad United  Quetta Gladiators       1    10
# 58      2016             1  Islamabad United  Quetta Gladiators       1    10
# 59      2016             1  Islamabad United  Quetta Gladiators       1    10
#
#     ball  runs  total_runs  wickets  is_four  is_six  is_wicket wicket_text  \
# 0      1     0           0        0    False   False      False     not out
# 1      2     0           0        0    False   False      False     not out
# 2      3     0           0        0    False   False      False     not out
# 3      4     0           0        0    False   False      False     not out
# 4      5     0           0        0    False   False      False     not out
# 5      6     0           0        0    False   False      False     not out
# 6      1     0           0        0    False   False      False     not out
# 7      2     1           1        0    False   False      False     not out
# 8      3     2           3        0    False   False      False     not out
# 9      4     0           3        0    False   False      False     not out
# 10     5     0           3        0    False   False      False     not out
# 11     6     2           5        0    False   False      False     not out
# 12     1     1           6        0    False   False      False     not out
# 13     2     4          10        0     True   False      False     not out
# 14     3     0          10        0    False   False      False     not out
# 15     4     0          10        0    False   False      False     not out
# 16     5     0          10        0    False   False      False     not out
# 17     6     1          11        0    False   False      False     not out
# 18     1     0          11        0    False   False      False     not out
# 19     2     0          11        0    False   False      False     not out
# 20     3     1          12        0    False   False      False     not out
# 21     4     0          12        0    False   False      False     not out
# 22     5     0          12        0    False   False      False     not out
# 23     6     0          12        0    False   False      False     not out
# 24     1     1          13        0    False   False      False     not out
# 25     2     0          13        0    False   False      False     not out
# 26     3     0          13        0    False   False      False     not out
# 27     4     6          19        0    False    True      False     not out
# 28     5     2          21        0    False   False      False     not out
# 29     6     0          21        1    False   False       True      caught
# 30     1     0          21        1    False   False      False     not out
# 31     2     0          21        1    False   False      False     not out
# 32     3     1          22        1    False   False      False     not out
# 33     4     0          22        1    False   False      False     not out
# 34     5     0          22        1    False   False      False     not out
# 35     6     0          22        1    False   False      False     not out
# 36     1     1          23        1    False   False      False     not out
# 37     2     1          24        1    False   False      False     not out
# 38     3     0          24        2    False   False       True      caught
# 39     4     0          24        2    False   False      False     not out
# 40     5     0          24        2    False   False      False     not out
# 41     6     0          24        2    False   False      False     not out
# 42     7     1          25        2    False   False      False     not out
# 43     1     0          25        2    False   False      False     not out
# 44     2     1          26        2    False   False      False     not out
# 45     3     0          26        2    False   False      False     not out
# 46     4     2          28        2    False   False      False     not out
# 47     5     0          28        2    False   False      False     not out
# 48     6     0          28        3    False   False       True      bowled
# 49     1     0          28        3    False   False      False     not out
# 50     2     1          29        3    False   False      False     not out
# 51     3     1          30        3    False   False      False     not out
# 52     4     1          31        3    False   False      False     not out
# 53     5     0          31        3    False   False      False     not out
# 54     6     1          32        3    False   False      False     not out
# 55     1     0          32        4    False   False       True      bowled
# 56     2     1          33        4    False   False      False     not out
# 57     3     1          34        4    False   False      False     not out
# 58     4     0          34        4    False   False      False     not out
# 59     5     1          35        4    False   False      False     not out
#
#         result
# 0   Gladiators
# 1   Gladiators
# 2   Gladiators
# 3   Gladiators
# 4   Gladiators
# 5   Gladiators
# 6   Gladiators
# 7   Gladiators
# 8   Gladiators
# 9   Gladiators
# 10  Gladiators
# 11  Gladiators
# 12  Gladiators
# 13  Gladiators
# 14  Gladiators
# 15  Gladiators
# 16  Gladiators
# 17  Gladiators
# 18  Gladiators
# 19  Gladiators
# 20  Gladiators
# 21  Gladiators
# 22  Gladiators
# 23  Gladiators
# 24  Gladiators
# 25  Gladiators
# 26  Gladiators
# 27  Gladiators
# 28  Gladiators
# 29  Gladiators
# 30  Gladiators
# 31  Gladiators
# 32  Gladiators
# 33  Gladiators
# 34  Gladiators
# 35  Gladiators
# 36  Gladiators
# 37  Gladiators
# 38  Gladiators
# 39  Gladiators
# 40  Gladiators
# 41  Gladiators
# 42  Gladiators
# 43  Gladiators
# 44  Gladiators
# 45  Gladiators
# 46  Gladiators
# 47  Gladiators
# 48  Gladiators
# 49  Gladiators
# 50  Gladiators
# 51  Gladiators
# 52  Gladiators
# 53  Gladiators
# 54  Gladiators
# 55  Gladiators
# 56  Gladiators
# 57  Gladiators
# 58  Gladiators
# 59  Gladiators

# %%
df.isnull().sum()
# Out:
# psl_year        0
# match_number    0
# team_1          0
# team_2          0
# inning          0
# over            0
# ball            0
# runs            0
# total_runs      0
# wickets         0
# is_four         0
# is_six          0
# is_wicket       0
# wicket_text     0
# result          0
# dtype: int64

# %%
 df["wickets_left"]=10-df["wickets"]

# %%
df.head(60)
# Out:
#     psl_year  match_number            team_1             team_2  inning  over  \
# 0       2016             1  Islamabad United  Quetta Gladiators       1     1
# 1       2016             1  Islamabad United  Quetta Gladiators       1     1
# 2       2016             1  Islamabad United  Quetta Gladiators       1     1
# 3       2016             1  Islamabad United  Quetta Gladiators       1     1
# 4       2016             1  Islamabad United  Quetta Gladiators       1     1
# 5       2016             1  Islamabad United  Quetta Gladiators       1     1
# 6       2016             1  Islamabad United  Quetta Gladiators       1     2
# 7       2016             1  Islamabad United  Quetta Gladiators       1     2
# 8       2016             1  Islamabad United  Quetta Gladiators       1     2
# 9       2016             1  Islamabad United  Quetta Gladiators       1     2
# 10      2016             1  Islamabad United  Quetta Gladiators       1     2
# 11      2016             1  Islamabad United  Quetta Gladiators       1     2
# 12      2016             1  Islamabad United  Quetta Gladiators       1     3
# 13      2016             1  Islamabad United  Quetta Gladiators       1     3
# 14      2016             1  Islamabad United  Quetta Gladiators       1     3
# 15      2016             1  Islamabad United  Quetta Gladiators       1     3
# 16      2016             1  Islamabad United  Quetta Gladiators       1     3
# 17      2016             1  Islamabad United  Quetta Gladiators       1     3
# 18      2016             1  Islamabad United  Quetta Gladiators       1     4
# 19      2016             1  Islamabad United  Quetta Gladiators       1     4
# 20      2016             1  Islamabad United  Quetta Gladiators       1     4
# 21      2016             1  Islamabad United  Quetta Gladiators       1     4
# 22      2016             1  Islamabad United  Quetta Gladiators       1     4
# 23      2016             1  Islamabad United  Quetta Gladiators       1     4
# 24      2016             1  Islamabad United  Quetta Gladiators       1     5
# 25      2016             1  Islamabad United  Quetta Gladiators       1     5
# 26      2016             1  Islamabad United  Quetta Gladiators       1     5
# 27      2016             1  Islamabad United  Quetta Gladiators       1     5
# 28      2016             1  Islamabad United  Quetta Gladiators       1     5
# 29      2016             1  Islamabad United  Quetta Gladiators       1     5
# 30      2016             1  Islamabad United  Quetta Gladiators       1     6
# 31      2016             1  Islamabad United  Quetta Gladiators       1     6
# 32      2016             1  Islamabad United  Quetta Gladiators       1     6
# 33      2016             1  Islamabad United  Quetta Gladiators       1     6
# 34      2016             1  Islamabad United  Quetta Gladiators       1     6
# 35      2016             1  Islamabad United  Quetta Gladiators       1     6
# 36      2016             1  Islamabad United  Quetta Gladiators       1     7
# 37      2016             1  Islamabad United  Quetta Gladiators       1     7
# 38      2016             1  Islamabad United  Quetta Gladiators       1     7
# 39      2016             1  Islamabad United  Quetta Gladiators       1     7
# 40      2016             1  Islamabad United  Quetta Gladiators       1     7
# 41      2016             1  Islamabad United  Quetta Gladiators       1     7
# 42      2016             1  Islamabad United  Quetta Gladiators       1     7
# 43      2016             1  Islamabad United  Quetta Gladiators       1     8
# 44      2016             1  Islamabad United  Quetta Gladiators       1     8
# 45      2016             1  Islamabad United  Quetta Gladiators       1     8
# 46      2016             1  Islamabad United  Quetta Gladiators       1     8
# 47      2016             1  Islamabad United  Quetta Gladiators       1     8
# 48      2016             1  Islamabad United  Quetta Gladiators       1     8
# 49      2016             1  Islamabad United  Quetta Gladiators       1     9
# 50      2016             1  Islamabad United  Quetta Gladiators       1     9
# 51      2016             1  Islamabad United  Quetta Gladiators       1     9
# 52      2016             1  Islamabad United  Quetta Gladiators       1     9
# 53      2016             1  Islamabad United  Quetta Gladiators       1     9
# 54      2016             1  Islamabad United  Quetta Gladiators       1     9
# 55      2016             1  Islamabad United  Quetta Gladiators       1    10
# 56      2016             1  Islamabad United  Quetta Gladiators       1    10
# 57      2016             1  Islamabad United  Quetta Gladiators       1    10
# 58      2016             1  Islamabad United  Quetta Gladiators       1    10
# 59      2016             1  Islamabad United  Quetta Gladiators       1    10
#
#     ball  runs  total_runs  wickets  is_four  is_six  is_wicket wicket_text  \
# 0      1     0           0        0    False   False      False     not out
# 1      2     0           0        0    False   False      False     not out
# 2      3     0           0        0    False   False      False     not out
# 3      4     0           0        0    False   False      False     not out
# 4      5     0           0        0    False   False      False     not out
# 5      6     0           0        0    False   False      False     not out
# 6      1     0           0        0    False   False      False     not out
# 7      2     1           1        0    False   False      False     not out
# 8      3     2           3        0    False   False      False     not out
# 9      4     0           3        0    False   False      False     not out
# 10     5     0           3        0    False   False      False     not out
# 11     6     2           5        0    False   False      False     not out
# 12     1     1           6        0    False   False      False     not out
# 13     2     4          10        0     True   False      False     not out
# 14     3     0          10        0    False   False      False     not out
# 15     4     0          10        0    False   False      False     not out
# 16     5     0          10        0    False   False      False     not out
# 17     6     1          11        0    False   False      False     not out
# 18     1     0          11        0    False   False      False     not out
# 19     2     0          11        0    False   False      False     not out
# 20     3     1          12        0    False   False      False     not out
# 21     4     0          12        0    False   False      False     not out
# 22     5     0          12        0    False   False      False     not out
# 23     6     0          12        0    False   False      False     not out
# 24     1     1          13        0    False   False      False     not out
# 25     2     0          13        0    False   False      False     not out
# 26     3     0          13        0    False   False      False     not out
# 27     4     6          19        0    False    True      False     not out
# 28     5     2          21        0    False   False      False     not out
# 29     6     0          21        1    False   False       True      caught
# 30     1     0          21        1    False   False      False     not out
# 31     2     0          21        1    False   False      False     not out
# 32     3     1          22        1    False   False      False     not out
# 33     4     0          22        1    False   False      False     not out
# 34     5     0          22        1    False   False      False     not out
# 35     6     0          22        1    False   False      False     not out
# 36     1     1          23        1    False   False      False     not out
# 37     2     1          24        1    False   False      False     not out
# 38     3     0          24        2    False   False       True      caught
# 39     4     0          24        2    False   False      False     not out
# 40     5     0          24        2    False   False      False     not out
# 41     6     0          24        2    False   False      False     not out
# 42     7     1          25        2    False   False      False     not out
# 43     1     0          25        2    False   False      False     not out
# 44     2     1          26        2    False   False      False     not out
# 45     3     0          26        2    False   False      False     not out
# 46     4     2          28        2    False   False      False     not out
# 47     5     0          28        2    False   False      False     not out
# 48     6     0          28        3    False   False       True      bowled
# 49     1     0          28        3    False   False      False     not out
# 50     2     1          29        3    False   False      False     not out
# 51     3     1          30        3    False   False      False     not out
# 52     4     1          31        3    False   False      False     not out
# 53     5     0          31        3    False   False      False     not out
# 54     6     1          32        3    False   False      False     not out
# 55     1     0          32        4    False   False       True      bowled
# 56     2     1          33        4    False   False      False     not out
# 57     3     1          34        4    False   False      False     not out
# 58     4     0          34        4    False   False      False     not out
# 59     5     1          35        4    False   False      False     not out
#
#         result  wickets_left
# 0   Gladiators            10
# 1   Gladiators            10
# 2   Gladiators            10
# 3   Gladiators            10
# 4   Gladiators            10
# 5   Gladiators            10
# 6   Gladiators            10
# 7   Gladiators            10
# 8   Gladiators            10
# 9   Gladiators            10
# 10  Gladiators            10
# 11  Gladiators            10
# 12  Gladiators            10
# 13  Gladiators            10
# 14  Gladiators            10
# 15  Gladiators            10
# 16  Gladiators            10
# 17  Gladiators            10
# 18  Gladiators            10
# 19  Gladiators            10
# 20  Gladiators            10
# 21  Gladiators            10
# 22  Gladiators            10
# 23  Gladiators            10
# 24  Gladiators            10
# 25  Gladiators            10
# 26  Gladiators            10
# 27  Gladiators            10
# 28  Gladiators            10
# 29  Gladiators             9
# 30  Gladiators             9
# 31  Gladiators             9
# 32  Gladiators             9
# 33  Gladiators             9
# 34  Gladiators             9
# 35  Gladiators             9
# 36  Gladiators             9
# 37  Gladiators             9
# 38  Gladiators             8
# 39  Gladiators             8
# 40  Gladiators             8
# 41  Gladiators             8
# 42  Gladiators             8
# 43  Gladiators             8
# 44  Gladiators             8
# 45  Gladiators             8
# 46  Gladiators             8
# 47  Gladiators             8
# 48  Gladiators             7
# 49  Gladiators             7
# 50  Gladiators             7
# 51  Gladiators             7
# 52  Gladiators             7
# 53  Gladiators             7
# 54  Gladiators             7
# 55  Gladiators             6
# 56  Gladiators             6
# 57  Gladiators             6
# 58  Gladiators             6
# 59  Gladiators             6

# %%
df['balls'] = df['ball'].apply(lambda x: min(x, 6))

# %%
df["over_ball"] = df["over"] + (df["balls"]/6)

# %%
df[df["ball"] == 10]
# Out:
#        psl_year  match_number             team_1             team_2  inning  \
# 9837       2017            19  Quetta Gladiators     Peshawar Zalmi       2
# 10291      2017            21  Quetta Gladiators     Peshawar Zalmi       2
# 12872      2018             8      Karachi Kings   Lahore Qalandars       2
# 25475      2019            28      Karachi Kings  Quetta Gladiators       2
# 36783      2021            12  Quetta Gladiators   Islamabad United       2
#
#        over  ball  runs  total_runs  wickets  is_four  is_six  is_wicket  \
# 9837      1    10     0           9        0    False   False      False
# 10291     4    10     1          30        2    False   False      False
# 12872     2    10     2          23        1    False   False      False
# 25475    19    10     4         186        4     True   False      False
# 36783    17    10     1         157        4    False   False      False
#
#       wicket_text      result  wickets_left  balls  over_ball
# 9837      not out       Zalmi            10      6        2.0
# 10291     not out  Gladiators             8      6        5.0
# 12872     not out       Kings             9      6        3.0
# 25475     not out       Kings             6      6       20.0
# 36783     not out      United             6      6       18.0

# %%
df["crr"]=df["total_runs"]/df["over_ball"]

# %%
df.head(60)
# Out:
#     psl_year  match_number            team_1             team_2  inning  over  \
# 0       2016             1  Islamabad United  Quetta Gladiators       1     1
# 1       2016             1  Islamabad United  Quetta Gladiators       1     1
# 2       2016             1  Islamabad United  Quetta Gladiators       1     1
# 3       2016             1  Islamabad United  Quetta Gladiators       1     1
# 4       2016             1  Islamabad United  Quetta Gladiators       1     1
# 5       2016             1  Islamabad United  Quetta Gladiators       1     1
# 6       2016             1  Islamabad United  Quetta Gladiators       1     2
# 7       2016             1  Islamabad United  Quetta Gladiators       1     2
# 8       2016             1  Islamabad United  Quetta Gladiators       1     2
# 9       2016             1  Islamabad United  Quetta Gladiators       1     2
# 10      2016             1  Islamabad United  Quetta Gladiators       1     2
# 11      2016             1  Islamabad United  Quetta Gladiators       1     2
# 12      2016             1  Islamabad United  Quetta Gladiators       1     3
# 13      2016             1  Islamabad United  Quetta Gladiators       1     3
# 14      2016             1  Islamabad United  Quetta Gladiators       1     3
# 15      2016             1  Islamabad United  Quetta Gladiators       1     3
# 16      2016             1  Islamabad United  Quetta Gladiators       1     3
# 17      2016             1  Islamabad United  Quetta Gladiators       1     3
# 18      2016             1  Islamabad United  Quetta Gladiators       1     4
# 19      2016             1  Islamabad United  Quetta Gladiators       1     4
# 20      2016             1  Islamabad United  Quetta Gladiators       1     4
# 21      2016             1  Islamabad United  Quetta Gladiators       1     4
# 22      2016             1  Islamabad United  Quetta Gladiators       1     4
# 23      2016             1  Islamabad United  Quetta Gladiators       1     4
# 24      2016             1  Islamabad United  Quetta Gladiators       1     5
# 25      2016             1  Islamabad United  Quetta Gladiators       1     5
# 26      2016             1  Islamabad United  Quetta Gladiators       1     5
# 27      2016             1  Islamabad United  Quetta Gladiators       1     5
# 28      2016             1  Islamabad United  Quetta Gladiators       1     5
# 29      2016             1  Islamabad United  Quetta Gladiators       1     5
# 30      2016             1  Islamabad United  Quetta Gladiators       1     6
# 31      2016             1  Islamabad United  Quetta Gladiators       1     6
# 32      2016             1  Islamabad United  Quetta Gladiators       1     6
# 33      2016             1  Islamabad United  Quetta Gladiators       1     6
# 34      2016             1  Islamabad United  Quetta Gladiators       1     6
# 35      2016             1  Islamabad United  Quetta Gladiators       1     6
# 36      2016             1  Islamabad United  Quetta Gladiators       1     7
# 37      2016             1  Islamabad United  Quetta Gladiators       1     7
# 38      2016             1  Islamabad United  Quetta Gladiators       1     7
# 39      2016             1  Islamabad United  Quetta Gladiators       1     7
# 40      2016             1  Islamabad United  Quetta Gladiators       1     7
# 41      2016             1  Islamabad United  Quetta Gladiators       1     7
# 42      2016             1  Islamabad United  Quetta Gladiators       1     7
# 43      2016             1  Islamabad United  Quetta Gladiators       1     8
# 44      2016             1  Islamabad United  Quetta Gladiators       1     8
# 45      2016             1  Islamabad United  Quetta Gladiators       1     8
# 46      2016             1  Islamabad United  Quetta Gladiators       1     8
# 47      2016             1  Islamabad United  Quetta Gladiators       1     8
# 48      2016             1  Islamabad United  Quetta Gladiators       1     8
# 49      2016             1  Islamabad United  Quetta Gladiators       1     9
# 50      2016             1  Islamabad United  Quetta Gladiators       1     9
# 51      2016             1  Islamabad United  Quetta Gladiators       1     9
# 52      2016             1  Islamabad United  Quetta Gladiators       1     9
# 53      2016             1  Islamabad United  Quetta Gladiators       1     9
# 54      2016             1  Islamabad United  Quetta Gladiators       1     9
# 55      2016             1  Islamabad United  Quetta Gladiators       1    10
# 56      2016             1  Islamabad United  Quetta Gladiators       1    10
# 57      2016             1  Islamabad United  Quetta Gladiators       1    10
# 58      2016             1  Islamabad United  Quetta Gladiators       1    10
# 59      2016             1  Islamabad United  Quetta Gladiators       1    10
#
#     ball  runs  total_runs  wickets  is_four  is_six  is_wicket wicket_text  \
# 0      1     0           0        0    False   False      False     not out
# 1      2     0           0        0    False   False      False     not out
# 2      3     0           0        0    False   False      False     not out
# 3      4     0           0        0    False   False      False     not out
# 4      5     0           0        0    False   False      False     not out
# 5      6     0           0        0    False   False      False     not out
# 6      1     0           0        0    False   False      False     not out
# 7      2     1           1        0    False   False      False     not out
# 8      3     2           3        0    False   False      False     not out
# 9      4     0           3        0    False   False      False     not out
# 10     5     0           3        0    False   False      False     not out
# 11     6     2           5        0    False   False      False     not out
# 12     1     1           6        0    False   False      False     not out
# 13     2     4          10        0     True   False      False     not out
# 14     3     0          10        0    False   False      False     not out
# 15     4     0          10        0    False   False      False     not out
# 16     5     0          10        0    False   False      False     not out
# 17     6     1          11        0    False   False      False     not out
# 18     1     0          11        0    False   False      False     not out
# 19     2     0          11        0    False   False      False     not out
# 20     3     1          12        0    False   False      False     not out
# 21     4     0          12        0    False   False      False     not out
# 22     5     0          12        0    False   False      False     not out
# 23     6     0          12        0    False   False      False     not out
# 24     1     1          13        0    False   False      False     not out
# 25     2     0          13        0    False   False      False     not out
# 26     3     0          13        0    False   False      False     not out
# 27     4     6          19        0    False    True      False     not out
# 28     5     2          21        0    False   False      False     not out
# 29     6     0          21        1    False   False       True      caught
# 30     1     0          21        1    False   False      False     not out
# 31     2     0          21        1    False   False      False     not out
# 32     3     1          22        1    False   False      False     not out
# 33     4     0          22        1    False   False      False     not out
# 34     5     0          22        1    False   False      False     not out
# 35     6     0          22        1    False   False      False     not out
# 36     1     1          23        1    False   False      False     not out
# 37     2     1          24        1    False   False      False     not out
# 38     3     0          24        2    False   False       True      caught
# 39     4     0          24        2    False   False      False     not out
# 40     5     0          24        2    False   False      False     not out
# 41     6     0          24        2    False   False      False     not out
# 42     7     1          25        2    False   False      False     not out
# 43     1     0          25        2    False   False      False     not out
# 44     2     1          26        2    False   False      False     not out
# 45     3     0          26        2    False   False      False     not out
# 46     4     2          28        2    False   False      False     not out
# 47     5     0          28        2    False   False      False     not out
# 48     6     0          28        3    False   False       True      bowled
# 49     1     0          28        3    False   False      False     not out
# 50     2     1          29        3    False   False      False     not out
# 51     3     1          30        3    False   False      False     not out
# 52     4     1          31        3    False   False      False     not out
# 53     5     0          31        3    False   False      False     not out
# 54     6     1          32        3    False   False      False     not out
# 55     1     0          32        4    False   False       True      bowled
# 56     2     1          33        4    False   False      False     not out
# 57     3     1          34        4    False   False      False     not out
# 58     4     0          34        4    False   False      False     not out
# 59     5     1          35        4    False   False      False     not out
#
#         result  wickets_left  balls  over_ball       crr
# 0   Gladiators            10      1   1.166667  0.000000
# 1   Gladiators            10      2   1.333333  0.000000
# 2   Gladiators            10      3   1.500000  0.000000
# 3   Gladiators            10      4   1.666667  0.000000
# 4   Gladiators            10      5   1.833333  0.000000
# 5   Gladiators            10      6   2.000000  0.000000
# 6   Gladiators            10      1   2.166667  0.000000
# 7   Gladiators            10      2   2.333333  0.428571
# 8   Gladiators            10      3   2.500000  1.200000
# 9   Gladiators            10      4   2.666667  1.125000
# 10  Gladiators            10      5   2.833333  1.058824
# 11  Gladiators            10      6   3.000000  1.666667
# 12  Gladiators            10      1   3.166667  1.894737
# 13  Gladiators            10      2   3.333333  3.000000
# 14  Gladiators            10      3   3.500000  2.857143
# 15  Gladiators            10      4   3.666667  2.727273
# 16  Gladiators            10      5   3.833333  2.608696
# 17  Gladiators            10      6   4.000000  2.750000
# 18  Gladiators            10      1   4.166667  2.640000
# 19  Gladiators            10      2   4.333333  2.538462
# 20  Gladiators            10      3   4.500000  2.666667
# 21  Gladiators            10      4   4.666667  2.571429
# 22  Gladiators            10      5   4.833333  2.482759
# 23  Gladiators            10      6   5.000000  2.400000
# 24  Gladiators            10      1   5.166667  2.516129
# 25  Gladiators            10      2   5.333333  2.437500
# 26  Gladiators            10      3   5.500000  2.363636
# 27  Gladiators            10      4   5.666667  3.352941
# 28  Gladiators            10      5   5.833333  3.600000
# 29  Gladiators             9      6   6.000000  3.500000
# 30  Gladiators             9      1   6.166667  3.405405
# 31  Gladiators             9      2   6.333333  3.315789
# 32  Gladiators             9      3   6.500000  3.384615
# 33  Gladiators             9      4   6.666667  3.300000
# 34  Gladiators             9      5   6.833333  3.219512
# 35  Gladiators             9      6   7.000000  3.142857
# 36  Gladiators             9      1   7.166667  3.209302
# 37  Gladiators             9      2   7.333333  3.272727
# 38  Gladiators             8      3   7.500000  3.200000
# 39  Gladiators             8      4   7.666667  3.130435
# 40  Gladiators             8      5   7.833333  3.063830
# 41  Gladiators             8      6   8.000000  3.000000
# 42  Gladiators             8      6   8.000000  3.125000
# 43  Gladiators             8      1   8.166667  3.061224
# 44  Gladiators             8      2   8.333333  3.120000
# 45  Gladiators             8      3   8.500000  3.058824
# 46  Gladiators             8      4   8.666667  3.230769
# 47  Gladiators             8      5   8.833333  3.169811
# 48  Gladiators             7      6   9.000000  3.111111
# 49  Gladiators             7      1   9.166667  3.054545
# 50  Gladiators             7      2   9.333333  3.107143
# 51  Gladiators             7      3   9.500000  3.157895
# 52  Gladiators             7      4   9.666667  3.206897
# 53  Gladiators             7      5   9.833333  3.152542
# 54  Gladiators             7      6  10.000000  3.200000
# 55  Gladiators             6      1  10.166667  3.147541
# 56  Gladiators             6      2  10.333333  3.193548
# 57  Gladiators             6      3  10.500000  3.238095
# 58  Gladiators             6      4  10.666667  3.187500
# 59  Gladiators             6      5  10.833333  3.230769

# %%
df["one"] = 1

# %%
df.loc[df['ball']>6,'one']=0

# %%
df[df['ball'] == 10]
# Out:
#        psl_year  match_number             team_1             team_2  inning  \
# 9837       2017            19  Quetta Gladiators     Peshawar Zalmi       2
# 10291      2017            21  Quetta Gladiators     Peshawar Zalmi       2
# 12872      2018             8      Karachi Kings   Lahore Qalandars       2
# 25475      2019            28      Karachi Kings  Quetta Gladiators       2
# 36783      2021            12  Quetta Gladiators   Islamabad United       2
#
#        over  ball  runs  total_runs  wickets  is_four  is_six  is_wicket  \
# 9837      1    10     0           9        0    False   False      False
# 10291     4    10     1          30        2    False   False      False
# 12872     2    10     2          23        1    False   False      False
# 25475    19    10     4         186        4     True   False      False
# 36783    17    10     1         157        4    False   False      False
#
#       wicket_text      result  wickets_left  balls  over_ball       crr  one
# 9837      not out       Zalmi            10      6        2.0  4.500000    0
# 10291     not out  Gladiators             8      6        5.0  6.000000    0
# 12872     not out       Kings             9      6        3.0  7.666667    0
# 25475     not out       Kings             6      6       20.0  9.300000    0
# 36783     not out      United             6      6       18.0  8.722222    0

# %%
df['number_of_balls']=df.groupby(['psl_year','match_number','inning'])['one'].cumsum()

# %%
df[df['number_of_balls']==121]
# Out:
# Empty DataFrame
# Columns: [psl_year, match_number, team_1, team_2, inning, over, ball, runs, total_runs, wickets, is_four, is_six, is_wicket, wicket_text, result, wickets_left, balls, over_ball, crr, one, number_of_balls]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['balls_left'] = 120 - df['number_of_balls']

# %%
df.head(10)
# Out:
#    psl_year  match_number            team_1             team_2  inning  over  \
# 0      2016             1  Islamabad United  Quetta Gladiators       1     1
# 1      2016             1  Islamabad United  Quetta Gladiators       1     1
# 2      2016             1  Islamabad United  Quetta Gladiators       1     1
# 3      2016             1  Islamabad United  Quetta Gladiators       1     1
# 4      2016             1  Islamabad United  Quetta Gladiators       1     1
# 5      2016             1  Islamabad United  Quetta Gladiators       1     1
# 6      2016             1  Islamabad United  Quetta Gladiators       1     2
# 7      2016             1  Islamabad United  Quetta Gladiators       1     2
# 8      2016             1  Islamabad United  Quetta Gladiators       1     2
# 9      2016             1  Islamabad United  Quetta Gladiators       1     2
#
#    ball  runs  total_runs  wickets  ...  is_wicket  wicket_text      result  \
# 0     1     0           0        0  ...      False      not out  Gladiators
# 1     2     0           0        0  ...      False      not out  Gladiators
# 2     3     0           0        0  ...      False      not out  Gladiators
# 3     4     0           0        0  ...      False      not out  Gladiators
# 4     5     0           0        0  ...      False      not out  Gladiators
# 5     6     0           0        0  ...      False      not out  Gladiators
# 6     1     0           0        0  ...      False      not out  Gladiators
# 7     2     1           1        0  ...      False      not out  Gladiators
# 8     3     2           3        0  ...      False      not out  Gladiators
# 9     4     0           3        0  ...      False      not out  Gladiators
#
#   wickets_left balls  over_ball       crr  one  number_of_balls  balls_left
# 0           10     1   1.166667  0.000000    1                1         119
# 1           10     2   1.333333  0.000000    1                2         118
# 2           10     3   1.500000  0.000000    1                3         117
# 3           10     4   1.666667  0.000000    1                4         116
# 4           10     5   1.833333  0.000000    1                5         115
# 5           10     6   2.000000  0.000000    1                6         114
# 6           10     1   2.166667  0.000000    1                7         113
# 7           10     2   2.333333  0.428571    1                8         112
# 8           10     3   2.500000  1.200000    1                9         111
# 9           10     4   2.666667  1.125000    1               10         110
#
# [10 rows x 22 columns]

# %%
df['over_id'] = (df['psl_year'].astype(str) + df['match_number'].astype(str)  + df['inning'].astype(str)  + df['over'].astype(str)).astype(int)

# %%
df['inning_id'] = (df['psl_year'].astype(str) + df['match_number'].astype(str)  + df['inning'].astype(str)).astype(int)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(10)
# Out:
#    psl_year  match_number            team_1             team_2  inning  over  \
# 0      2016             1  Islamabad United  Quetta Gladiators       1     1
# 1      2016             1  Islamabad United  Quetta Gladiators       1     1
# 2      2016             1  Islamabad United  Quetta Gladiators       1     1
# 3      2016             1  Islamabad United  Quetta Gladiators       1     1
# 4      2016             1  Islamabad United  Quetta Gladiators       1     1
# 5      2016             1  Islamabad United  Quetta Gladiators       1     1
# 6      2016             1  Islamabad United  Quetta Gladiators       1     2
# 7      2016             1  Islamabad United  Quetta Gladiators       1     2
# 8      2016             1  Islamabad United  Quetta Gladiators       1     2
# 9      2016             1  Islamabad United  Quetta Gladiators       1     2
#
#    ball  runs  total_runs  wickets  is_four  is_six  is_wicket wicket_text  \
# 0     1     0           0        0    False   False      False     not out
# 1     2     0           0        0    False   False      False     not out
# 2     3     0           0        0    False   False      False     not out
# 3     4     0           0        0    False   False      False     not out
# 4     5     0           0        0    False   False      False     not out
# 5     6     0           0        0    False   False      False     not out
# 6     1     0           0        0    False   False      False     not out
# 7     2     1           1        0    False   False      False     not out
# 8     3     2           3        0    False   False      False     not out
# 9     4     0           3        0    False   False      False     not out
#
#        result  wickets_left  balls  over_ball       crr  one  number_of_balls  \
# 0  Gladiators            10      1   1.166667  0.000000    1                1
# 1  Gladiators            10      2   1.333333  0.000000    1                2
# 2  Gladiators            10      3   1.500000  0.000000    1                3
# 3  Gladiators            10      4   1.666667  0.000000    1                4
# 4  Gladiators            10      5   1.833333  0.000000    1                5
# 5  Gladiators            10      6   2.000000  0.000000    1                6
# 6  Gladiators            10      1   2.166667  0.000000    1                7
# 7  Gladiators            10      2   2.333333  0.428571    1                8
# 8  Gladiators            10      3   2.500000  1.200000    1                9
# 9  Gladiators            10      4   2.666667  1.125000    1               10
#
#    balls_left  over_id  inning_id
# 0         119  2016111     201611
# 1         118  2016111     201611
# 2         117  2016111     201611
# 3         116  2016111     201611
# 4         115  2016111     201611
# 5         114  2016111     201611
# 6         113  2016112     201611
# 7         112  2016112     201611
# 8         111  2016112     201611
# 9         110  2016112     201611

# %%
df = df.groupby(['over_id'])['runs'].sum().reset_index().merge(df,on='over_id')

# %%
df.rename(columns={'runs_x':'runs_over','runs_y':'runs_ball'},inplace=True)

# %%
df.columns
# Out:
# Index(['over_id', 'runs_over', 'psl_year', 'match_number', 'team_1', 'team_2',
#        'inning', 'over', 'ball', 'runs_ball', 'total_runs', 'wickets',
#        'is_four', 'is_six', 'is_wicket', 'wicket_text', 'result',
#        'wickets_left', 'balls', 'over_ball', 'crr', 'one', 'number_of_balls',
#        'balls_left', 'inning_id'],
#       dtype='object')

# %%
groups=df.groupby('inning_id')
inning_ids=df['inning_id'].unique()
last_five=[]
for id in inning_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs_ball'].values.tolist())
# Out:
# C:\Users\UC\AppData\Local\Temp\ipykernel_11044\1793115505.py:5: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['result', 'team_1', 'team_2', 'wicket_text'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs_ball'].values.tolist())

# %%
df['last_five']=last_five

# %%
df.head()
# Out:
#    over_id  runs_over  psl_year  match_number            team_1  \
# 0  2016111          0      2016             1  Islamabad United
# 1  2016111          0      2016             1  Islamabad United
# 2  2016111          0      2016             1  Islamabad United
# 3  2016111          0      2016             1  Islamabad United
# 4  2016111          0      2016             1  Islamabad United
#
#               team_2  inning  over  ball  runs_ball  total_runs  wickets  \
# 0  Quetta Gladiators       1     1     1          0           0        0
# 1  Quetta Gladiators       1     1     2          0           0        0
# 2  Quetta Gladiators       1     1     3          0           0        0
# 3  Quetta Gladiators       1     1     4          0           0        0
# 4  Quetta Gladiators       1     1     5          0           0        0
#
#    is_four  is_six  is_wicket wicket_text      result  wickets_left  balls  \
# 0    False   False      False     not out  Gladiators            10      1
# 1    False   False      False     not out  Gladiators            10      2
# 2    False   False      False     not out  Gladiators            10      3
# 3    False   False      False     not out  Gladiators            10      4
# 4    False   False      False     not out  Gladiators            10      5
#
#    over_ball  crr  one  number_of_balls  balls_left  inning_id  last_five
# 0   1.166667  0.0    1                1         119     201611        NaN
# 1   1.333333  0.0    1                2         118     201611        NaN
# 2   1.500000  0.0    1                3         117     201611        NaN
# 3   1.666667  0.0    1                4         116     201611        NaN
# 4   1.833333  0.0    1                5         115     201611        NaN

# %%
df = df.groupby('inning_id').sum()['runs_ball'].reset_index().merge(df,on='inning_id')

# %%
df.head()
# Out:
#    inning_id  runs_ball_x  over_id  runs_over  psl_year  match_number  \
# 0     201611          128  2016111          0      2016             1
# 1     201611          128  2016111          0      2016             1
# 2     201611          128  2016111          0      2016             1
# 3     201611          128  2016111          0      2016             1
# 4     201611          128  2016111          0      2016             1
#
#              team_1             team_2  inning  over  ball  runs_ball_y  \
# 0  Islamabad United  Quetta Gladiators       1     1     1            0
# 1  Islamabad United  Quetta Gladiators       1     1     2            0
# 2  Islamabad United  Quetta Gladiators       1     1     3            0
# 3  Islamabad United  Quetta Gladiators       1     1     4            0
# 4  Islamabad United  Quetta Gladiators       1     1     5            0
#
#    total_runs  wickets  is_four  is_six  is_wicket wicket_text      result  \
# 0           0        0    False   False      False     not out  Gladiators
# 1           0        0    False   False      False     not out  Gladiators
# 2           0        0    False   False      False     not out  Gladiators
# 3           0        0    False   False      False     not out  Gladiators
# 4           0        0    False   False      False     not out  Gladiators
#
#    wickets_left  balls  over_ball  crr  one  number_of_balls  balls_left  \
# 0            10      1   1.166667  0.0    1                1         119
# 1            10      2   1.333333  0.0    1                2         118
# 2            10      3   1.500000  0.0    1                3         117
# 3            10      4   1.666667  0.0    1                4         116
# 4            10      5   1.833333  0.0    1                5         115
#
#    last_five
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.rename(columns={'runs_ball_x': 'Target','runs_ball_y':'runs_ball'},inplace=True)

# %%
df.sample(5)
# Out:
#        inning_id  Target    over_id  runs_over  psl_year  match_number  \
# 6605      201922     176    2019229          3      2019             2
# 16036    2016152     160  201615216         12      2016            15
# 6207      201911     166    2019115          6      2019             1
# 11610     202161     196   20216118         13      2021             6
# 49255    2022302     158  202230216         13      2022            30
#
#                  team_1            team_2  inning  over  ball  runs_ball  \
# 6605      Karachi Kings    Multan Sultans       2     9     4          0
# 16036  Lahore Qalandars    Peshawar Zalmi       2    16     1          1
# 6207   Lahore Qalandars  Islamabad United       1     5     1          1
# 11610     Karachi Kings  Islamabad United       1    18     3          1
# 49255    Peshawar Zalmi  Lahore Qalandars       2    16     4          4
#
#        total_runs  wickets  is_four  is_six  is_wicket wicket_text     result  \
# 6605           52        2    False   False      False     not out      Kings
# 16036         124        4    False   False      False     not out  Qalandars
# 6207           35        0    False   False      False     not out     United
# 11610         172        0    False   False      False     not out     United
# 49255         102        6     True   False      False     not out       tied
#
#        wickets_left  balls  over_ball       crr  one  number_of_balls  \
# 6605              8      4   9.666667  5.379310    1               52
# 16036             6      1  16.166667  7.670103    1               91
# 6207             10      1   5.166667  6.774194    1               25
# 11610            10      3  18.500000  9.297297    1              105
# 49255             4      4  16.666667  6.120000    1               94
#
#        balls_left  last_five
# 6605           68        NaN
# 16036          29       46.0
# 6207           95       25.0
# 11610          15       40.0
# 49255          26       47.0

# %%
df.isnull().sum()
# Out:
# inning_id              0
# Target                 0
# over_id                0
# runs_over              0
# psl_year               0
# match_number           0
# team_1                 0
# team_2                 0
# inning                 0
# over                   0
# ball                   0
# runs_ball              0
# total_runs             0
# wickets                0
# is_four                0
# is_six                 0
# is_wicket              0
# wicket_text            0
# result                 0
# wickets_left           0
# balls                  0
# over_ball              0
# crr                    0
# one                    0
# number_of_balls        0
# balls_left             0
# last_five          12412
# dtype: int64

# %%
df.head()
# Out:
#    inning_id  Target  over_id  runs_over  psl_year  match_number  \
# 0     201611     128  2016111          0      2016             1
# 1     201611     128  2016111          0      2016             1
# 2     201611     128  2016111          0      2016             1
# 3     201611     128  2016111          0      2016             1
# 4     201611     128  2016111          0      2016             1
#
#              team_1             team_2  inning  over  ball  runs_ball  \
# 0  Islamabad United  Quetta Gladiators       1     1     1          0
# 1  Islamabad United  Quetta Gladiators       1     1     2          0
# 2  Islamabad United  Quetta Gladiators       1     1     3          0
# 3  Islamabad United  Quetta Gladiators       1     1     4          0
# 4  Islamabad United  Quetta Gladiators       1     1     5          0
#
#    total_runs  wickets  is_four  is_six  is_wicket wicket_text      result  \
# 0           0        0    False   False      False     not out  Gladiators
# 1           0        0    False   False      False     not out  Gladiators
# 2           0        0    False   False      False     not out  Gladiators
# 3           0        0    False   False      False     not out  Gladiators
# 4           0        0    False   False      False     not out  Gladiators
#
#    wickets_left  balls  over_ball  crr  one  number_of_balls  balls_left  \
# 0            10      1   1.166667  0.0    1                1         119
# 1            10      2   1.333333  0.0    1                2         118
# 2            10      3   1.500000  0.0    1                3         117
# 3            10      4   1.666667  0.0    1                4         116
# 4            10      5   1.833333  0.0    1                5         115
#
#    last_five
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df['match_id'] = (df['psl_year'].astype(str) + df['match_number'].astype(str)).astype(int)

# %%
df.head()
# Out:
#    inning_id  Target  over_id  runs_over  psl_year  match_number  \
# 0     201611     128  2016111          0      2016             1
# 1     201611     128  2016111          0      2016             1
# 2     201611     128  2016111          0      2016             1
# 3     201611     128  2016111          0      2016             1
# 4     201611     128  2016111          0      2016             1
#
#              team_1             team_2  inning  over  ball  runs_ball  \
# 0  Islamabad United  Quetta Gladiators       1     1     1          0
# 1  Islamabad United  Quetta Gladiators       1     1     2          0
# 2  Islamabad United  Quetta Gladiators       1     1     3          0
# 3  Islamabad United  Quetta Gladiators       1     1     4          0
# 4  Islamabad United  Quetta Gladiators       1     1     5          0
#
#    total_runs  wickets  is_four  is_six  is_wicket wicket_text      result  \
# 0           0        0    False   False      False     not out  Gladiators
# 1           0        0    False   False      False     not out  Gladiators
# 2           0        0    False   False      False     not out  Gladiators
# 3           0        0    False   False      False     not out  Gladiators
# 4           0        0    False   False      False     not out  Gladiators
#
#    wickets_left  balls  over_ball  crr  one  number_of_balls  balls_left  \
# 0            10      1   1.166667  0.0    1                1         119
# 1            10      2   1.333333  0.0    1                2         118
# 2            10      3   1.500000  0.0    1                3         117
# 3            10      4   1.666667  0.0    1                4         116
# 4            10      5   1.833333  0.0    1                5         115
#
#    last_five  match_id
# 0        NaN     20161
# 1        NaN     20161
# 2        NaN     20161
# 3        NaN     20161
# 4        NaN     20161

# %%
temp = df[['match_id','inning','Target']]

# %%
temp
# Out:
#        match_id  inning  Target
# 0         20161       1     128
# 1         20161       1     128
# 2         20161       1     128
# 3         20161       1     128
# 4         20161       1     128
# ...         ...     ...     ...
# 50257    202234       2     138
# 50258    202234       2     138
# 50259    202234       2     138
# 50260    202234       2     138
# 50261    202234       2     138
#
# [50262 rows x 3 columns]

# %%
temp =temp[temp['inning']==1]

# %%
temp.head()
# Out:
#    match_id  inning  Target
# 0     20161       1     128
# 1     20161       1     128
# 2     20161       1     128
# 3     20161       1     128
# 4     20161       1     128

# %%
temp.rename(columns={'Target':'Targets'},inplace=True)
# Out:
# C:\Users\UC\AppData\Local\Temp\ipykernel_11044\1062286648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp.rename(columns={'Target':'Targets'},inplace=True)

# %%
temp.head()
# Out:
#    match_id  inning  Targets
# 0     20161       1      128
# 1     20161       1      128
# 2     20161       1      128
# 3     20161       1      128
# 4     20161       1      128

# %%
df.shape
# Out:
# (50262, 28)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = temp.merge(df,on='match_id')

# %%
df.duplicated().sum()
# Out:
# 6083919

# %%
df.shape
# Out:
# (6134181, 30)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (50262, 30)

# %%
df.head()
# Out:
#    match_id  inning_x  Targets  inning_id  Target  over_id  runs_over  \
# 0     20161         1      128     201611     128  2016111          0
# 1     20161         1      128     201611     128  2016111          0
# 2     20161         1      128     201611     128  2016111          0
# 3     20161         1      128     201611     128  2016111          0
# 4     20161         1      128     201611     128  2016111          0
#
#    psl_year  match_number            team_1             team_2  inning_y  \
# 0      2016             1  Islamabad United  Quetta Gladiators         1
# 1      2016             1  Islamabad United  Quetta Gladiators         1
# 2      2016             1  Islamabad United  Quetta Gladiators         1
# 3      2016             1  Islamabad United  Quetta Gladiators         1
# 4      2016             1  Islamabad United  Quetta Gladiators         1
#
#    over  ball  runs_ball  total_runs  wickets  is_four  is_six  is_wicket  \
# 0     1     1          0           0        0    False   False      False
# 1     1     2          0           0        0    False   False      False
# 2     1     3          0           0        0    False   False      False
# 3     1     4          0           0        0    False   False      False
# 4     1     5          0           0        0    False   False      False
#
#   wicket_text      result  wickets_left  balls  over_ball  crr  one  \
# 0     not out  Gladiators            10      1   1.166667  0.0    1
# 1     not out  Gladiators            10      2   1.333333  0.0    1
# 2     not out  Gladiators            10      3   1.500000  0.0    1
# 3     not out  Gladiators            10      4   1.666667  0.0    1
# 4     not out  Gladiators            10      5   1.833333  0.0    1
#
#    number_of_balls  balls_left  last_five
# 0                1         119        NaN
# 1                2         118        NaN
# 2                3         117        NaN
# 3                4         116        NaN
# 4                5         115        NaN

# %%
df.rename(columns={'inning_y':'inning'},inplace=True)

# %%
df.rename(columns={'Target':'Total_score'},inplace=True)

# %%
df[(df['inning'] == 1) & (df['match_id'] == 201722)]
# Out:
#          match_id  inning_x  Targets  inning_id  Total_score    over_id  \
# 2546295    201722         1      126    2017221          126   20172211
# 2546296    201722         1      126    2017221          126   20172211
# 2546297    201722         1      126    2017221          126   20172211
# 2546298    201722         1      126    2017221          126   20172211
# 2546299    201722         1      126    2017221          126   20172211
# ...           ...       ...      ...        ...          ...        ...
# 2546412    201722         1      126    2017221          126  201722119
# 2546413    201722         1      126    2017221          126  201722120
# 2546414    201722         1      126    2017221          126  201722120
# 2546415    201722         1      126    2017221          126  201722120
# 2546416    201722         1      126    2017221          126  201722120
#
#          runs_over  psl_year  match_number         team_1            team_2  \
# 2546295          4      2017            22  Karachi Kings  Islamabad United
# 2546296          4      2017            22  Karachi Kings  Islamabad United
# 2546297          4      2017            22  Karachi Kings  Islamabad United
# 2546298          4      2017            22  Karachi Kings  Islamabad United
# 2546299          4      2017            22  Karachi Kings  Islamabad United
# ...            ...       ...           ...            ...               ...
# 2546412          3      2017            22  Karachi Kings  Islamabad United
# 2546413          1      2017            22  Karachi Kings  Islamabad United
# 2546414          1      2017            22  Karachi Kings  Islamabad United
# 2546415          1      2017            22  Karachi Kings  Islamabad United
# 2546416          1      2017            22  Karachi Kings  Islamabad United
#
#          inning  over  ball  runs_ball  total_runs  wickets  is_four  is_six  \
# 2546295       1     1     1          0           0        0    False   False
# 2546296       1     1     2          0           0        0    False   False
# 2546297       1     1     3          0           0        0    False   False
# 2546298       1     1     4          0           0        0    False   False
# 2546299       1     1     5          0           0        0    False   False
# ...         ...   ...   ...        ...         ...      ...      ...     ...
# 2546412       1    19     7          1         125        8    False   False
# 2546413       1    20     1          0         125        9    False   False
# 2546414       1    20     2          1         126        9    False   False
# 2546415       1    20     3          0         126        9    False   False
# 2546416       1    20     4          0         126       10    False   False
#
#          is_wicket wicket_text result  wickets_left  balls  over_ball  \
# 2546295      False     not out  Kings            10      1   1.166667
# 2546296      False     not out  Kings            10      2   1.333333
# 2546297      False     not out  Kings            10      3   1.500000
# 2546298      False     not out  Kings            10      4   1.666667
# 2546299      False     not out  Kings            10      5   1.833333
# ...            ...         ...    ...           ...    ...        ...
# 2546412      False     not out  Kings             2      6  20.000000
# 2546413       True      caught  Kings             1      1  20.166667
# 2546414      False     not out  Kings             1      2  20.333333
# 2546415      False     not out  Kings             1      3  20.500000
# 2546416       True      bowled  Kings             0      4  20.666667
#
#               crr  one  number_of_balls  balls_left  last_five
# 2546295  0.000000    1                1         119       70.0
# 2546296  0.000000    1                2         118       69.0
# 2546297  0.000000    1                3         117       71.0
# 2546298  0.000000    1                4         116        NaN
# 2546299  0.000000    1                5         115        NaN
# ...           ...  ...              ...         ...        ...
# 2546412  6.250000    0              114           6        NaN
# 2546413  6.198347    1              115           5        NaN
# 2546414  6.196721    1              116           4       40.0
# 2546415  6.146341    1              117           3       40.0
# 2546416  6.096774    1              118           2       40.0
#
# [122 rows x 30 columns]

# %%
df = df[df['inning']==2]

# %%
df.head()
# Out:
#      match_id  inning_x  Targets  inning_id  Total_score  over_id  runs_over  \
# 124     20161         1      128     201612          132  2016121          6
# 125     20161         1      128     201612          132  2016121          6
# 126     20161         1      128     201612          132  2016121          6
# 127     20161         1      128     201612          132  2016121          6
# 128     20161         1      128     201612          132  2016121          6
#
#      psl_year  match_number            team_1             team_2  inning  \
# 124      2016             1  Islamabad United  Quetta Gladiators       2
# 125      2016             1  Islamabad United  Quetta Gladiators       2
# 126      2016             1  Islamabad United  Quetta Gladiators       2
# 127      2016             1  Islamabad United  Quetta Gladiators       2
# 128      2016             1  Islamabad United  Quetta Gladiators       2
#
#      over  ball  runs_ball  total_runs  wickets  is_four  is_six  is_wicket  \
# 124     1     1          0           0        0    False   False      False
# 125     1     2          0           0        0    False   False      False
# 126     1     3          0           0        0    False   False      False
# 127     1     4          2           2        0    False   False      False
# 128     1     5          0           2        0    False   False      False
#
#     wicket_text      result  wickets_left  balls  over_ball       crr  one  \
# 124     not out  Gladiators            10      1   1.166667  0.000000    1
# 125     not out  Gladiators            10      2   1.333333  0.000000    1
# 126     not out  Gladiators            10      3   1.500000  0.000000    1
# 127     not out  Gladiators            10      4   1.666667  1.200000    1
# 128     not out  Gladiators            10      5   1.833333  1.090909    1
#
#      number_of_balls  balls_left  last_five
# 124                1         119       19.0
# 125                2         118       20.0
# 126                3         117       15.0
# 127                4         116       13.0
# 128                5         115       14.0

# %%
df['runs_left'] = df['Targets']-df['total_runs']

# %%
df.drop(df[df['runs_left'] < 0].index, inplace=True)

# %%
df.shape
# Out:
# (24049, 31)

# %%
df['rem_over_ball'] = 21 - df['over_ball']

# %%
df.tail(12)
# Out:
#          match_id  inning_x  Targets  inning_id  Total_score    over_id  \
# 6104889    202234         1      180    2022342          138  202234218
# 6104890    202234         1      180    2022342          138  202234218
# 6104891    202234         1      180    2022342          138  202234218
# 6104892    202234         1      180    2022342          138  202234219
# 6104893    202234         1      180    2022342          138  202234219
# 6104894    202234         1      180    2022342          138  202234219
# 6104895    202234         1      180    2022342          138  202234219
# 6104896    202234         1      180    2022342          138  202234219
# 6104897    202234         1      180    2022342          138  202234219
# 6104898    202234         1      180    2022342          138  202234220
# 6104899    202234         1      180    2022342          138  202234220
# 6104900    202234         1      180    2022342          138  202234220
#
#          runs_over  psl_year  match_number            team_1          team_2  \
# 6104889         12      2022            34  Lahore Qalandars  Multan Sultans
# 6104890         12      2022            34  Lahore Qalandars  Multan Sultans
# 6104891         12      2022            34  Lahore Qalandars  Multan Sultans
# 6104892          6      2022            34  Lahore Qalandars  Multan Sultans
# 6104893          6      2022            34  Lahore Qalandars  Multan Sultans
# 6104894          6      2022            34  Lahore Qalandars  Multan Sultans
# 6104895          6      2022            34  Lahore Qalandars  Multan Sultans
# 6104896          6      2022            34  Lahore Qalandars  Multan Sultans
# 6104897          6      2022            34  Lahore Qalandars  Multan Sultans
# 6104898          0      2022            34  Lahore Qalandars  Multan Sultans
# 6104899          0      2022            34  Lahore Qalandars  Multan Sultans
# 6104900          0      2022            34  Lahore Qalandars  Multan Sultans
#
#          inning  over  ball  runs_ball  total_runs  wickets  is_four  is_six  \
# 6104889       2    18     4          1         124        8    False   False
# 6104890       2    18     5          4         128        8     True   False
# 6104891       2    18     6          4         132        8     True   False
# 6104892       2    19     1          0         132        8    False   False
# 6104893       2    19     2          1         133        8    False   False
# 6104894       2    19     3          1         134        8    False   False
# 6104895       2    19     4          4         138        8     True   False
# 6104896       2    19     5          0         138        9    False   False
# 6104897       2    19     6          0         138        9    False   False
# 6104898       2    20     1          0         138        9    False   False
# 6104899       2    20     2          0         138        9    False   False
# 6104900       2    20     3          0         138       10    False   False
#
#          is_wicket wicket_text     result  wickets_left  balls  over_ball  \
# 6104889      False     not out  Qalandars             2      4  18.666667
# 6104890      False     not out  Qalandars             2      5  18.833333
# 6104891      False     not out  Qalandars             2      6  19.000000
# 6104892      False     not out  Qalandars             2      1  19.166667
# 6104893      False     not out  Qalandars             2      2  19.333333
# 6104894      False     not out  Qalandars             2      3  19.500000
# 6104895      False     not out  Qalandars             2      4  19.666667
# 6104896       True      bowled  Qalandars             1      5  19.833333
# 6104897      False     not out  Qalandars             1      6  20.000000
# 6104898      False     not out  Qalandars             1      1  20.166667
# 6104899      False     not out  Qalandars             1      2  20.333333
# 6104900       True      caught  Qalandars             0      3  20.500000
#
#               crr  one  number_of_balls  balls_left  last_five  runs_left  \
# 6104889  6.642857    1              106          14       47.0         56
# 6104890  6.796460    1              107          13       50.0         52
# 6104891  6.947368    1              108          12       50.0         48
# 6104892  6.886957    1              109          11       50.0         48
# 6104893  6.879310    1              110          10       47.0         47
# 6104894  6.871795    1              111           9       42.0         46
# 6104895  7.016949    1              112           8       45.0         42
# 6104896  6.957983    1              113           7       44.0         42
# 6104897  6.900000    1              114           6       43.0         42
# 6104898  6.842975    1              115           5       42.0         42
# 6104899  6.786885    1              116           4       41.0         42
# 6104900  6.731707    1              117           3       40.0         42
#
#          rem_over_ball
# 6104889       2.333333
# 6104890       2.166667
# 6104891       2.000000
# 6104892       1.833333
# 6104893       1.666667
# 6104894       1.500000
# 6104895       1.333333
# 6104896       1.166667
# 6104897       1.000000
# 6104898       0.833333
# 6104899       0.666667
# 6104900       0.500000

# %%
df['rrr'] = df['runs_left']/df['rem_over_ball']

# %%
df.sample(6)
# Out:
#          match_id  inning_x  Targets  inning_id  Total_score    over_id  \
# 1659525     20226         1      170     202262          174   20226210
# 782650      20192         1      183     201922          176    2019225
# 4260862    202020         1      195    2020202           85   20202023
# 3596524    201920         1      133    2019202          134   20192026
# 4901373    202119         1      197    2021192          136   20211928
# 2939371    201822         1      188    2018222          125  201822219
#
#          runs_over  psl_year  match_number            team_1  \
# 1659525          4      2022             6     Karachi Kings
# 782650           8      2019             2     Karachi Kings
# 4260862         11      2020            20  Islamabad United
# 3596524          1      2019            20  Lahore Qalandars
# 4901373          8      2021            19    Peshawar Zalmi
# 2939371         11      2018            22     Karachi Kings
#
#                     team_2  inning  over  ball  runs_ball  total_runs  \
# 1659525   Lahore Qalandars       2    10     6          1          77
# 782650      Multan Sultans       2     5     2          4          19
# 4260862     Peshawar Zalmi       2     3     2          1          20
# 3596524      Karachi Kings       2     6     3          0          28
# 4901373  Quetta Gladiators       2     8     4          1          61
# 2939371     Multan Sultans       2    19     2          0         110
#
#          wickets  is_four  is_six  is_wicket wicket_text     result  \
# 1659525        2    False   False      False     not out  Qalandars
# 782650         1     True   False      False     not out      Kings
# 4260862        0    False   False      False     not out      Zalmi
# 3596524        2    False   False      False     not out      Kings
# 4901373        0    False   False      False     not out      Zalmi
# 2939371        9    False   False      False     not out      Kings
#
#          wickets_left  balls  over_ball       crr  one  number_of_balls  \
# 1659525             8      6  11.000000  7.000000    1               60
# 782650              9      2   5.333333  3.562500    1               26
# 4260862            10      2   3.333333  6.000000    1               14
# 3596524             8      3   6.500000  4.307692    1               33
# 4901373            10      4   8.666667  7.038462    1               46
# 2939371             1      2  19.333333  5.689655    1              110
#
#          balls_left  last_five  runs_left  rem_over_ball        rrr
# 1659525          60       14.0         93      10.000000   9.300000
# 782650           94       43.0        164      15.666667  10.468085
# 4260862         106       26.0        175      17.666667   9.905660
# 3596524          87       48.0        105      14.500000   7.241379
# 4901373          74       34.0        136      12.333333  11.027027
# 2939371          10       35.0         78       1.666667  46.800000

# %%
df['result'].unique()
# Out:
# array(['Gladiators', 'Kings', 'Zalmi', 'United', 'Qalandars', 'Sultans',
#        'tied'], dtype=object)

# %%
df['win'] = np.where(df['Targets'] > df['Total_score'], 0, 1)

# %%
df.sample(5)
# Out:
#          match_id  inning_x  Targets  inning_id  Total_score    over_id  \
# 943866      20198         1      160     201982          161    2019829
# 4932881    202120         1      152    2021202          124  202120210
# 2436566    201718         1      155    2017182          158   20171822
# 3984339    201933         1      214    2019332          166  201933215
# 5132837    202127         1      176    2021272          169   20212724
#
#          runs_over  psl_year  match_number            team_1  \
# 943866           4      2019             8    Multan Sultans
# 4932881          3      2021            20  Islamabad United
# 2436566         10      2017            18  Lahore Qalandars
# 3984339          6      2019            33    Peshawar Zalmi
# 5132837          3      2021            27     Karachi Kings
#
#                     team_2  inning  over  ball  runs_ball  total_runs  \
# 943866   Quetta Gladiators       2     9     1          1          80
# 4932881   Lahore Qalandars       2    10     6          0          86
# 2436566      Karachi Kings       2     2     5          1          14
# 3984339   Islamabad United       2    15     5          1         138
# 5132837   Lahore Qalandars       2     4     6          1          37
#
#          wickets  is_four  is_six  is_wicket wicket_text      result  \
# 943866         1    False   False      False     not out  Gladiators
# 4932881        2    False   False      False     not out      United
# 2436566        0    False   False      False     not out       Kings
# 3984339        5    False   False      False     not out       Zalmi
# 5132837        0    False   False      False     not out       Kings
#
#          wickets_left  balls  over_ball       crr  one  number_of_balls  \
# 943866              9      1   9.166667  8.727273    1               49
# 4932881             8      6  11.000000  7.818182    1               60
# 2436566            10      5   2.833333  4.941176    1               11
# 3984339             5      5  15.833333  8.715789    1               89
# 5132837            10      6   5.000000  7.400000    1               24
#
#          balls_left  last_five  runs_left  rem_over_ball        rrr  win
# 943866           71        NaN         80      11.833333   6.760563    1
# 4932881          60        NaN         66      10.000000   6.600000    0
# 2436566         109       33.0        141      18.166667   7.761468    1
# 3984339          31       46.0         76       5.166667  14.709677    0
# 5132837          96        NaN        139      16.000000   8.687500    0

# %%
df_final = df[['team_1','team_2','runs_left','balls_left','wickets_left','Targets','crr','rrr','last_five','win']]

# %%
df_final.isnull().sum()
# Out:
# team_1             0
# team_2             0
# runs_left          0
# balls_left         0
# wickets_left       0
# Targets            0
# crr                0
# rrr                3
# last_five       5995
# win                0
# dtype: int64

# %%
df_final.shape
# Out:
# (24049, 10)

# %%
#df_final.to_csv('finalPSLresult.csv',index=False)
